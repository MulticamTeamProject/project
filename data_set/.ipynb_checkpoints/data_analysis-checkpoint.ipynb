# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns


# %matplotlib inline

# %%
# 출국통계_202006 데이터 다뤄보기
jeonnam = pd.read_excel('./국내관광객/주요관광지점입장객_전남(2011-2019).xls', header=None).copy()
jeonnam.shape
# Out:
# (1338, 122)

# %%
jeonnam.head()
# Out:
#     0    1           2      3                      4      5          6    \
# 0    시도   군구         관광지  내/외국인  총계(2011.01 ~ 2019.12)  2011년        NaN
# 1   NaN  NaN         NaN    NaN                    NaN    인원계  2011년 01월
# 2  전라남도  목포시  1987 영화촬영지    내국인                265,927      -          -
# 3  전라남도  목포시  1987 영화촬영지     합계                265,927      -          -
# 4  전라남도  목포시   가톨릭 목포 성지    내국인                 95,045      -          -
#
#          7          8          9    ...        112        113        114  \
# 0        NaN        NaN        NaN  ...        NaN        NaN        NaN
# 1  2011년 02월  2011년 03월  2011년 04월  ...  2019년 03월  2019년 04월  2019년 05월
# 2          -          -          -  ...     16,704     13,683     20,657
# 3          -          -          -  ...     16,704     13,683     20,657
# 4          -          -          -  ...      5,289      4,505      6,116
#
#          115        116        117        118        119        120        121
# ...

# %%
jeonnam.drop(np.arange(4,57), inplace=True, axis=1)

# %%
jeonnam.head()
# Out:
#     0    1           2      3          60         61         62         63   \
# 0    시도   군구         관광지  내/외국인        NaN        NaN        NaN        NaN
# 1   NaN  NaN         NaN    NaN  2015년 03월  2015년 04월  2015년 05월  2015년 06월
# 2  전라남도  목포시  1987 영화촬영지    내국인          -          -          -          -
# 3  전라남도  목포시  1987 영화촬영지     합계          -          -          -          -
# 4  전라남도  목포시   가톨릭 목포 성지    내국인          -          -          -          -
#
#          64         65   ...        112        113        114        115  \
# 0        NaN        NaN  ...        NaN        NaN        NaN        NaN
# 1  2015년 07월  2015년 08월  ...  2019년 03월  2019년 04월  2019년 05월  2019년 06월
# 2          -          -  ...     16,704     13,683     20,657     13,301
# 3          -          -  ...     16,704     13,683     20,657     13,301
# 4          -          -  ...      5,289      4,505      6,116      7,965
#
#          116        117        118        119        120        121
# ...

# %%
asia_year = asia.tail(21).copy()
asia_month = asia.head(len(asia) - len(asia_year))
# Out:
# 1        년   월   법무부・KTO     Korea       일본     Japan       중국     China  \
# 220  2016년  누계  22383190  0.159124  5090302  0.271909  4775300  0.074453
# 221  2017년  누계  26496447  0.183765  7140438  0.402753  3863800 -0.190878
# 222  2018년  누계  28695983  0.083012  7538952  0.055811  4193500  0.085331
# 223  2019년  누계  28714247  0.000636  5584597 -0.259234        0  0.000000
# 224  2020년  누계   3820739 -0.745417   477800 -0.876303        0  0.000000
#
# 1        베트남   Vietnam  ...  사이프러스   Cyprus    부탄    Bhutan    요르단     Jordan  \
# 220  1543883  0.339770  ...    167  3.39474  1035  0.617188   9654  -0.155898
# 221  2415245  0.564396  ...      0        0  6048  4.843478  13999   0.450073
# 222  3435406  0.422384  ...      0        0   998 -0.834987  14985  0.0704336
# 223  4290802  0.248994  ...      0        0  1408  0.410822      0          -
# 224   819089 -0.260613  ...      0        0     0  0.000000      0          0
#
# 1       네팔      Nepal  예멘  Yemen
# ...

# %%
asia_year
# Out:
# 1        년   월   법무부・KTO     Korea       일본     Japan       중국     China  \
# 204  2000년  누계   5508242  0.269000  1064390  0.000000  1344721  0.000000
# 205  2001년  누계   6084476  0.104613  1133971  0.065372  1678836  0.248464
# 206  2002년  누계   7123407  0.170751  1271835  0.121576  2124310  0.265347
# 207  2003년  누계   7086133 -0.005233  1459333  0.147423  1945500 -0.084173
# 208  2004년  누계   8825585  0.245473  1588472  0.088492  2844893  0.462294
# 209  2005년  누계  10080143  0.142150  1747171  0.099907  3542785  0.245314
# 210  2006년  누계  11609879  0.151757  2117325  0.211859  3922017  0.107043
# 211  2007년  누계  13324977  0.147727  2600694  0.228292  4776752  0.217933
# 212  2008년  누계  11996094 -0.099729  2382397 -0.083938  3960392 -0.170903
# 213  2009년  누계   9494111 -0.208566  1586772 -0.333960  3197500 -0.192630
# 214  2010년  누계  12488364  0.315380  2439816  0.537597  4076400  0.274871
# 215  2011년  누계  12693733  0.016445  1658073 -0.320411  4185400  0.026739
# ...

# %%
asia_month.shape
# Out:
# (204, 54)

# %%
import matplotlib.font_manager as fm

#  한글글꼴로 변경
plt.rcParams['font.size'] = 12.0
# plt.rcParams['font.family'] = 'batang'
plt.rcParams['font.family'] = 'Malgun Gothic'
print(plt.rcParams['font.family'])
print(plt.rcParams['font.size'])
# Out:
# ['Malgun Gothic']
# 12.0

# %%
# year에 대한 그래프 그려보기
label = ['일본', '중국', '베트남', '태국', '홍콩']
x = asia_year['년'].loc[214:]
fig = plt.figure(figsize=(15,10))

for nation in label:
    y = list(asia_year[nation].loc[214:])
    fig, plt.plot(x, y, label=nation)
fig, plt.xlabel('년도')
fig, plt.ylabel('방문수')
fig, plt.legend()
fig, plt.show()
# Out:
# (<Figure size 1080x720 with 1 Axes>, None)

# %% [markdown]
# ## 추천하는 방식 logic
#
# - 순수 방문 인구수를 max값부터 순서로 상위 5개정도 or 증가율로 따지는 법
# - 사용자가 검색한 나라의 rating
# - 2개를 섞거나 또는 유저의 정보를 받아서 비슷한 군의 유저에게 아직 가보지않은 나라를 추천해주는 방식
# cf) 머신러닝 방문자 수와와의 관계있는 데이터를 모아야 - 날씨, 나라의 인기관광지 갯수
